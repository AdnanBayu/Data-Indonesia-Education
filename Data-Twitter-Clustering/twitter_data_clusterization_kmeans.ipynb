# %% [markdown]
# ### import dependencies

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
from scipy.spatial.distance import cdist

# %% [markdown]
# ### import data

# %%
csv = pd.read_csv('twitter_data_preprocessed.csv')
csv.head()
# Out:
#    Unnamed: 0  conversation_id_str                      created_at  \
# 0           0  1774403165552779625  Sun Mar 31 23:42:04 +0000 2024
# 1           1  1774366076832555399  Sun Mar 31 23:33:44 +0000 2024
# 2           2  1774577114903441629  Sun Mar 31 23:18:48 +0000 2024
# 3           3  1774571795284463848  Sun Mar 31 22:57:44 +0000 2024
# 4           4  1774357860631404836  Sun Mar 31 22:53:35 +0000 2024
#
#    favorite_count               id_str in_reply_to_screen_name lang  \
# 0               0  1774582967823974432              20686notes   in
# 1               3  1774580870550335888             as_sulthoni   in
# 2               0  1774577114903441629                     NaN   in
# 3               0  1774571810564260282            predicatment   in
# 4               0  1774570768145514695             piyopikavet   in
#
#                location  quote_count  reply_count  retweet_count  \
# 0  Tangerang, Indonesia            0            0              0
# 1             Indonesia            0            0              0
# 2              Surabaya            0            0              0
# 3   maap agak sibuk ges            0            1              0
# 4              バンジャーマシン            0            0              0
#
#                                            tweet_url          user_id_str  \
# 0  https://x.com/20686notes/status/17745829678239...  1352643811030102019
# 1  https://x.com/as_sulthoni/status/1774580870550...  1526640801270231040
# 2  https://x.com/miftah_force/status/177457711490...            770602400
# 3  https://x.com/predicatment/status/177457181056...  1740329033148358656
# 4  https://x.com/samyangnyaqamu/status/1774570768...  1385848355104776195
#
#          username                                  full_text_cleaned
# 0      20686notes  rokok legal mahal ya pindah ke rokok ilegal be...
# 1     as_sulthoni  jujur gw cuma ngisi waktu luang aja dan emang ...
# 2    miftah_force  konten kreator yang kata ngomongin edukasi did...
# 3    predicatment  gw jg gk justifikasi pilih satu bagus inti mah...
# 4  samyangnyaqamu                 terimakasih banyak edukasi nya pak

# %%
# get the text only and convert to numpy array
text = csv['full_text_cleaned'].to_numpy()
np.size(text)
# Out:
# 1062

# %% [markdown]
# ### vectorize the data

# %%
vectorizer = TfidfVectorizer(use_idf=False, norm= None, ngram_range=(1,2))
matrix = vectorizer.fit_transform(text).toarray()

# %% [markdown]
# ### kmeans clustering

# %%
cluster_numb = 5
model = KMeans(n_clusters=cluster_numb, max_iter=100000, n_init=1)
model.fit(matrix)
# Out:
# KMeans(max_iter=100000, n_clusters=5, n_init=1)

# %%
print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:,::-1]
terms = vectorizer.get_feature_names_out()
for i in range(cluster_numb):
    print("\n----------Cluster {}----------\n".format(i))
    for ind in order_centroids[i, :10]:
        print(terms[ind] + " - " + str(ind))
# Out:
# Top terms per cluster:
#
# ----------Cluster 0----------
#
# juga - 6741
# edukasi - 4226
# yang juga - 15108
# untuk sharing - 14595
# sekolah - 12422
# segera balas - 12331
# segera - 12330
# nanti segera - 9765
# kita yaa - 7745
# yaa - 15018
#
# ----------Cluster 1----------
#
# edukasi - 4226
# dan - 3181
# di - 3628
# co - 2783
# https - 5790
# https co - 5791
# yg - 15188
# yang - 15055
# ini - 6000
# ada - 266
#
# ----------Cluster 2----------
#
# bina serta - 2048
# https co - 5791
# sambang - 12070
# suci - 13255
# suci ramadhan - 13257
# 1445 2024 - 48
# pada bulan - 10502
# 1445 - 47
# beri - 1850
# beri edukasi - 1853
#
# ----------Cluster 3----------
#
# masyarakat - 9079
# yang - 15055
# tahu - 13433
# kepada masyarakat - 7548
# kepada - 7543
# ini - 6000
# harus - 5593
# beri - 1850
# dan - 3181
# masyarakat juga - 9092
#
# ----------Cluster 4----------
#
# yg - 15188
# muda - 9570
# udah - 14418
# ibu - 5832
# edukasi - 4226
# door - 4057
# di - 3628
# to - 14082
# makin - 8828
# yg akses - 15193

# %% [markdown]
# ### do prediction to categorize twitter sentiments

# %%
#this part is problematic
vectorizer.fit(text)
final_sentiment = []

for i in text:
    # print(i)
    y = vectorizer.transform([i])
    y = model.predict(y)
    # print(np.shape(y))
    final_sentiment.append(int(y[0]))

# %%
np.unique(final_sentiment)
# Out:
# array([0, 1, 2, 3, 4])

# %%
csv['cluster'] = final_sentiment
csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 csv['cluster'] = final_sentiment
#       2 csv
#
# NameError: name 'final_sentiment' is not defined

# %%
for i in range(1062):
    if csv['cluster'][i] == 0:
        print(csv['full_text_cleaned'][i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 for i in range(1062):
# ----> 2     if csv['cluster'][i] == 0:
#       3         print(csv['full_text_cleaned'][i])
#
# NameError: name 'csv' is not defined
