# %%
import pandas as pd
import numpy as np

# %%
#Survey Social Media Data (source: https://www.kaggle.com/datasets/rizkyalifr/datasurveimedsos)
socmed_survey = pd.read_csv('Kaggle_Survei_Medsos.csv')

#Google News Data
google_news = pd.read_csv('Data-Crawl-Google\multi_page_data_crawled.csv')

#Twitter Data
twitter_data = pd.read_csv("Data-Twitter-Preprocess/twitter_data_preprocessed.csv")
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\m'
# <>:5: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9660\3435383867.py:5: SyntaxWarning: invalid escape sequence '\m'
#   google_news = pd.read_csv('Data-Crawl-Google\multi_page_data_crawled.csv')

# %%
socmed_survey.head()
# Out:
#   Jenis_Kelamin          Pekerjaan     Sering Lupa_Waktu Waktu_Sekali_Pakai  \
# 0     Laki-laki  Pelajar/Mahasiswa  Instagram  Instagram        31-60 menit
# 1     Laki-laki  Pelajar/Mahasiswa  Instagram  Instagram         5-10 menit
# 2     Perempuan  Pelajar/Mahasiswa         WA         WA          < 5 menit
# 3     Perempuan   Ibu Rumah Tangga  Instagram  Instagram        11-30 menit
# 4     Laki-laki  Pelajar/Mahasiswa         WA  Instagram        31-60 menit
#
#   Waktu_Harian  Mengganggu_Produktivitas  Membuang_Waktu  \
# 0      > 2 jam                         4               5
# 1  31-60 menit                         3               3
# 2      > 3 jam                         3               4
# 3      > 3 jam                         4               5
# 4      > 2 jam                         4               5
#
#    Tidak_Bisa_Kontrol_Diri  Tidak_Sadar_Waktu  Fomo  Tanpa_Tujuan  \
# 0                        5                  5     5             5
# ...

# %%
google_news.head()
# Out:
#    Unnamed: 0                                       judul berita  \
# 0           0  Indonesia tunjukkan transformasi pendidikan le...
# 1           1  Kemendikbudristek Temukan 4 Kecurangan Penerim...
# 2           2  Kemendikbud Ungkap Pelanggaran Mahasiswa Pener...
# 3           3  Staf Khusus Nadiem Beberkan Tiga Tantangan Bes...
# 4           4  Pemuda Didorong Berperan Aktif dalam Kebijakan...
#
#             penerbit                                           sinopsis  \
# 0  ANTARA News Jambi  ANTARA - Indonesia menunjukkan sejumlah platfo...
# 1           detikcom  Balai Pembiayaan Pendidikan Tinggi (BPPT) Keme...
# 2         Kompas.com  Kemendikbud Ristek menungkap beragam pelanggar...
# 3          Medcom.id  Bali: Staf Khusus Mendikbudristek Bidang Kompe...
# 4         Borneonews  Billy Mambrasar mengajak pemuda berperan aktif...
#
#                                                 link
# 0  https://jambi.antaranews.com/rilis-pers/436953...
# ...

# %%
twitter_data.head()
# Out:
#    Unnamed: 0  conversation_id_str                      created_at  \
# 0           0  1774403165552779625  Sun Mar 31 23:42:04 +0000 2024
# 1           1  1774366076832555399  Sun Mar 31 23:33:44 +0000 2024
# 2           2  1774577114903441629  Sun Mar 31 23:18:48 +0000 2024
# 3           3  1774571795284463848  Sun Mar 31 22:57:44 +0000 2024
# 4           4  1774357860631404836  Sun Mar 31 22:53:35 +0000 2024
#
#    favorite_count               id_str in_reply_to_screen_name lang  \
# 0               0  1774582967823974432              20686notes   in
# 1               3  1774580870550335888             as_sulthoni   in
# 2               0  1774577114903441629                     NaN   in
# 3               0  1774571810564260282            predicatment   in
# 4               0  1774570768145514695             piyopikavet   in
#
#                location  quote_count  reply_count  retweet_count  \
# 0  Tangerang, Indonesia            0            0              0
# ...
